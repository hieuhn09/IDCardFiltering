# %%
from LightGlue.lightglue import LightGlue, SuperPoint, DISK
from LightGlue.lightglue.utils import load_image, rbd
import shutil
# Out:
# Downloading: "https://github.com/cvg/LightGlue/releases/download/v0.1_arxiv/superpoint_lightglue.pth" to C:\Users\Admin/.cache\torch\hub\checkpoints\superpoint_lightglue_v0-1_arxiv.pth
# 100%|██████████| 45.3M/45.3M [00:02<00:00, 18.2MB/s]
# Downloading: "https://raw.githubusercontent.com/cvlab-epfl/disk/master/depth-save.pth" to C:\Users\Admin/.cache\torch\hub\checkpoints\depth-save.pth
# 100%|██████████| 4.17M/4.17M [00:00<00:00, 17.4MB/s]
# Downloading: "https://github.com/cvg/LightGlue/releases/download/v0.1_arxiv/disk_lightglue.pth" to C:\Users\Admin/.cache\torch\hub\checkpoints\disk_lightglue_v0-1_arxiv.pth
# 100%|██████████| 45.4M/45.4M [00:02<00:00, 20.3MB/s]

# %%
def feature_matcher(template_path, image_path, extractor, matcher):
    """
    Function to match features between a template and an image.

    Args:
    template_path (str): Path to the template image.
    image_path (str): Path to the image to match.
    extractor (SuperPoint): SuperPoint extractor.
    matcher (LightGlue): LightGlue matcher.

    Returns:
    int: Number of matched features.
    """

    # load the images
    image0 = load_image(template_path)
    image1 = load_image(image_path)

    # extract local features
    feats0 = extractor.extract(image0)  
    feats1 = extractor.extract(image1)

    # match the features
    matches01 = matcher({'image0': feats0, 'image1': feats1})
    feats0, feats1, matches01 = [rbd(x) for x in [feats0, feats1, matches01]]  # remove batch dimension

    return len(matches01["matches"])

# %%
def classify_id_cards(template_path, input_folder_path, green_output_folder, white_output_folder, threshold=800):
    """
    Classify ID cards as green or white based on the template matching result.
    
    Args:
    template_path (str): Path to the template image.
    input_folder_path (str): Path to the input folder.
    green_output_folder (str): Path to the green output folder.
    white_output_folder (str): Path to the white output folder.
    threshold (int): Threshold for the template matching result.

    """

    # SuperPoint+LightGlue
    extractor = SuperPoint(max_num_keypoints=2048).eval()  # load the extractor
    matcher = LightGlue(features='superpoint').eval()  # load the matcher


    for filename in os.listdir(input_folder_path):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            input_path = os.path.join(input_folder_path, filename)

            match_num = feature_matcher(template_path, input_path, extractor, matcher)

            if match_num > threshold:
                print(f'Classified {filename} as green ID card: {match_num} matches')
                output_path = os.path.join(green_output_folder, filename)
            else:
                print(f'Classified {filename} as white ID card: {match_num} matches')
                output_path = os.path.join(white_output_folder, filename)

            shutil.copy(input_path, output_path)

# Test to find the best threshold
template_path = 'template.jpeg'
input_folder_path = 'test'
green_output_folder = 'green_output_folder'
white_output_folder = 'white_output_folder'
classify_id_cards(template_path, input_folder_path, green_output_folder, white_output_folder)
# Out:
# Classified renderfile (12270).jpeg as green ID card: 884 matches
# Classified renderfile (12271).jpeg as white ID card: 705 matches
# Classified renderfile (12276).jpeg as white ID card: 406 matches
# Classified renderfile (12278).jpeg as white ID card: 419 matches
# Classified renderfile (12279).jpeg as white ID card: 408 matches
# Classified renderfile (12280).jpeg as white ID card: 391 matches
# Classified renderfile (12281).jpeg as green ID card: 904 matches
# Classified renderfile (12283).jpeg as white ID card: 330 matches
# Classified renderfile (12284).jpeg as white ID card: 356 matches
# Classified renderfile (12285).jpeg as white ID card: 361 matches
# Classified renderfile (12286).jpeg as white ID card: 368 matches
# Classified renderfile (12287).jpeg as white ID card: 396 matches
# Classified renderfile (12288).jpeg as white ID card: 383 matches
# Classified renderfile (12335).jpeg as white ID card: 769 matches
# Classified renderfile (12459).jpeg as white ID card: 630 matches
# Classified renderfile (12463).jpeg as green ID card: 943 matches
# Classified renderfile (12488).jpeg as white ID card: 358 matches
# Classified renderfile (12489).jpeg as white ID card: 332 matches
# Classified renderfile (12490).jpeg as white ID card: 298 matches
# Classified renderfile (12492).jpeg as white ID card: 354 matches
# Classified renderfile (12493).jpeg as white ID card: 373 matches
# Classified renderfile (12495).jpeg as white ID card: 392 matches
# Classified renderfile (12497).jpeg as white ID card: 296 matches
# Classified renderfile (12498).jpeg as white ID card: 362 matches
# Classified renderfile (12503).jpeg as white ID card: 384 matches
# Classified renderfile (12504).jpeg as white ID card: 394 matches
# Classified renderfile (12505).jpeg as white ID card: 325 matches
# Classified renderfile (12508).jpeg as white ID card: 380 matches
# Classified renderfile (12510).jpeg as white ID card: 371 matches
# Classified renderfile (12511).jpeg as white ID card: 367 matches
# Classified renderfile (12513).jpeg as white ID card: 333 matches
# Classified renderfile (12515).jpeg as white ID card: 344 matches
# Classified renderfile (12516).jpeg as white ID card: 419 matches
# Classified renderfile (12517).jpeg as white ID card: 308 matches
# Classified renderfile (12518).jpeg as white ID card: 340 matches
# Classified renderfile (12519).jpeg as white ID card: 325 matches
# Classified renderfile (12523).jpeg as white ID card: 391 matches
# Classified renderfile (12524).jpeg as white ID card: 391 matches
# Classified renderfile (12527).jpeg as white ID card: 343 matches
# Classified renderfile (12528).jpeg as white ID card: 348 matches
# Classified renderfile (12529).jpeg as white ID card: 398 matches
# Classified renderfile (12532).jpeg as white ID card: 424 matches
# Classified renderfile (12535).jpeg as white ID card: 391 matches
# Classified renderfile (12537).jpeg as white ID card: 377 matches
# Classified renderfile (12539).jpeg as white ID card: 403 matches
# Classified renderfile (12540).jpeg as white ID card: 382 matches
# Classified renderfile (12544).jpeg as white ID card: 365 matches
# Classified renderfile (12548).jpeg as white ID card: 771 matches
# Classified renderfile (12549).jpeg as white ID card: 407 matches
# Classified renderfile (12550).jpeg as white ID card: 362 matches
# Classified renderfile (12552).jpeg as white ID card: 427 matches
# Classified renderfile (12553).jpeg as white ID card: 358 matches
# Classified renderfile (12555).jpeg as white ID card: 357 matches
# Classified renderfile (12556).jpeg as white ID card: 690 matches
# Classified renderfile (12559).jpeg as white ID card: 327 matches
# Classified renderfile (12560).jpeg as green ID card: 802 matches
# Classified renderfile (12562).jpeg as white ID card: 356 matches
# Classified renderfile (12563).jpeg as white ID card: 650 matches
# Classified renderfile (12564).jpeg as white ID card: 703 matches
# Classified renderfile (12565).jpeg as white ID card: 755 matches
# Classified renderfile (12566).jpeg as green ID card: 823 matches
# Classified renderfile (12568).jpeg as white ID card: 224 matches
# Classified renderfile (12570).jpeg as white ID card: 444 matches
# Classified renderfile (12571).jpeg as white ID card: 371 matches
# Classified renderfile (12572).jpeg as white ID card: 646 matches
# Classified renderfile (12573).jpeg as white ID card: 355 matches
# Classified renderfile (12575).jpeg as white ID card: 693 matches
# Classified renderfile (12577).jpeg as white ID card: 776 matches
# Classified renderfile (12579).jpeg as white ID card: 315 matches
# Classified renderfile (12580).jpeg as white ID card: 765 matches
# Classified renderfile (12581).jpeg as white ID card: 707 matches
# Classified renderfile (12583).jpeg as white ID card: 302 matches
# Classified renderfile (12584).jpeg as white ID card: 401 matches
# Classified renderfile (12585).jpeg as white ID card: 323 matches
# Classified renderfile (12586).jpeg as white ID card: 778 matches
# Classified renderfile (12589).jpeg as white ID card: 341 matches
# Classified renderfile (12590).jpeg as green ID card: 896 matches
# Classified renderfile (12591).jpeg as white ID card: 460 matches
# Classified renderfile (12592).jpeg as white ID card: 376 matches
# Classified renderfile (12593).jpeg as white ID card: 383 matches
# Classified renderfile (12594).jpeg as green ID card: 881 matches
# Classified renderfile (12595).jpeg as white ID card: 794 matches
# Classified renderfile (12596).jpeg as white ID card: 394 matches
# Classified renderfile (12598).jpeg as white ID card: 360 matches
# Classified renderfile (12599).jpeg as green ID card: 837 matches
# Classified renderfile (12601).jpeg as white ID card: 427 matches
# Classified renderfile (12604).jpeg as white ID card: 396 matches
# Classified renderfile (12606).jpeg as white ID card: 360 matches
# Classified renderfile (12608).jpeg as white ID card: 334 matches
# Classified renderfile (12609).jpeg as white ID card: 364 matches
# Classified renderfile (12612).jpeg as white ID card: 350 matches

# %%
# Final classification
threshold = 567
template_path = 'template.jpeg'
input_folder_path = 'input_folder'
green_output_folder = 'green_output_folder_final'
white_output_folder = 'white_output_folder_final'
classify_id_cards(template_path, input_folder_path, green_output_folder, white_output_folder, threshold=threshold)
